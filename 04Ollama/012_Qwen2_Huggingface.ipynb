# %%
from langchain_ollama import ChatOllama
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
import time

# 모델 일관성을 위한 상수 정의
MODEL_NAME = "qwen2.5:1.5b" # LLM model 
BASE_URL = "http://localhost:11434" # url
EMBEDDING_MODEL_NAME = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2" # 사용할 huggingfaceembeddings model

# %%
import requests

response = requests.get("http://127.0.0.1:11434")
print(response.text)
# Out:
# Ollama is running

# %%
print("=" * 60)
print(" 로컬 RAG 시스템 초기화")
print("=" * 60)

# 1. 문서 로딩
print("==> 1. 문서 로딩 → PDF 읽기...")
try:
    loader = PyPDFLoader('./data/tutorial-korean.pdf')
    documents = loader.load()
    print(f"총 {len(documents)}페이지 로드 완료")
except Exception as e:
    print(f"PDF 로딩 실패: {e}")
    print("'../data/tutorial-korean.pdf' 파일이 존재하는지 확인해주세요.")
    exit(1)
# Out:
# ============================================================
#  로컬 RAG 시스템 초기화
# ============================================================
# ==> 1. 문서 로딩 → PDF 읽기...
# 총 39페이지 로드 완료

# %%
# 2. 문서 분할
print("==> 2. 문서 분할 → 작은 청크로 나누기")
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=150,
    separators=["\n\n", "\n", ".", " ", ""]
)

chunks = text_splitter.split_documents(documents)
print(f"{len(chunks)}개 청크 생성 완료")
print(f"평균 청크 길이: {sum(len(chunk.page_content) for chunk in chunks) / len(chunks):.0f}자")

# 3. 임베딩 설정
print("==> 3. 임베딩 설정...")
print("임베딩 모델 다운로드 중... (최초 실행 시 시간이 소요됩니다)")
try:
    embeddings = HuggingFaceEmbeddings(
        model_name=EMBEDDING_MODEL_NAME,
        model_kwargs={'device': 'cpu'},
        encode_kwargs={'normalize_embeddings': True}
    )
    print("HuggingFace 임베딩 모델 설정 완료")
except Exception as e:
    print(f"임베딩 모델 설정 실패: {e}")
    print("인터넷 연결을 확인하거나 다음 패키지를 설치해주세요:")
    print("pip install sentence-transformers")
    exit(1)
# Out:
# ==> 2. 문서 분할 → 작은 청크로 나누기
# 76개 청크 생성 완료
# 평균 청크 길이: 605자
# ==> 3. 임베딩 설정...
# 임베딩 모델 다운로드 중... (최초 실행 시 시간이 소요됩니다)
# HuggingFace 임베딩 모델 설정 완료

# %%
# 4. 벡터스토어 생성
print("==> 4. 벡터스토어 생성...")
print("임베딩 생성 중... (시간이 소요됩니다)")

start_time = time.time()
try:
    vectorstore = FAISS.from_documents(chunks, embeddings)
    embedding_time = time.time() - start_time
    print(f"FAISS 벡터스토어 생성 완료 ({len(chunks)}개 벡터)")
    print(f"임베딩 소요 시간: {embedding_time:.1f}초")
except Exception as e:
    print(f"벡터스토어 생성 실패: {e}")
    print("모델이 설치되어 있는지 확인해주세요: ollama pull qwen2.5:latest")
    exit(1)
# Out:
# ==> 4. 벡터스토어 생성...
# 임베딩 생성 중... (시간이 소요됩니다)
# FAISS 벡터스토어 생성 완료 (76개 벡터)
# 임베딩 소요 시간: 3.0초

# %%
# 5. 검색기 설정
print("==> 5. 검색기 설정...")
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 6}
)
print("검색기 설정 완료")

# 6. LLM 설정
print("==> 6. LLM 설정...")
try:
    llm = ChatOllama(
        model=MODEL_NAME,
        temperature=0.1,
        num_predict=800
    )
    print("LLM 설정 완료")
except Exception as e:
    print(f"LLM 설정 실패: {e}")
    exit(1)
# Out:
# ==> 5. 검색기 설정...
# 검색기 설정 완료
# ==> 6. LLM 설정...
# LLM 설정 완료

# %%
# 7. 프롬프트 설정
print("==> 7. 프롬프트 설정...")
prompt_template = """당신은 BlueJ 프로그래밍 환경 전문가입니다.
아래 문서 내용을 바탕으로 정확하고 친절한 답변을 제공해주세요.

문서 내용:
{context}

질문: {question}

답변 규칙:
1. 문서 내용만을 근거로 답변하세요
2. 단계별로 설명하세요  
3. 구체적인 메뉴명, 버튼명을 포함하세요
4. 문서에 없는 정보는 "문서에서 찾을 수 없습니다"라고 하세요

답변:"""

prompt = PromptTemplate(
    template=prompt_template,
    input_variables=["context", "question"]
)
print("프롬프트 설정 완료")
# Out:
# ==> 7. 프롬프트 설정...
# 프롬프트 설정 완료

# %%
# 8. QA 체인 생성
print("==> 8. QA 체인 생성...")
try:
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=retriever,
        chain_type_kwargs={"prompt": prompt},
        return_source_documents=True
    )
    print("RAG 파이프라인 구축 완료")
except Exception as e:
    print(f"QA 체인 생성 실패: {e}")
    exit(1)
# Out:
# ==> 8. QA 체인 생성...
# RAG 파이프라인 구축 완료

# %%
# 9. 테스트 실행
print("\n" + "=" * 60)
print(" 로컬 RAG 시스템 테스트")
print("=" * 60)

test_questions = [
    "BlueJ에서 객체를 생성하는 방법은 무엇인가요?",
    "컴파일 오류가 발생했을 때 어떻게 확인할 수 있나요?"
]

total_start_time = time.time()

for i, question in enumerate(test_questions, 1):
    print(f"\n【테스트 {i}/{len(test_questions)}】")
    print(f"질문: {question}")
    print("답변 생성 중...")
    
    question_start_time = time.time()
    
    try:
        result = qa_chain.invoke({"query": question})
        answer = result["result"]
        source_docs = result["source_documents"]
        
        question_time = time.time() - question_start_time
        
        print(f"\n답변: (응답시간: {question_time:.1f}초)")
        print("-" * 50)
        print(answer)
        
        print(f"\n참조 문서:")
        for j, doc in enumerate(source_docs[:2], 1):
            page = doc.metadata.get('page', 'N/A')
            preview = doc.page_content[:50].replace('\n', ' ')
            print(f"   {j}. 페이지 {page}: {preview}...")
            
    except Exception as e:
        print(f"답변 생성 실패: {e}")
    
    print("\n" + "-" * 40)

total_time = time.time() - total_start_time
print(f"\n테스트 완료! (총 소요시간: {total_time:.1f}초)")

# 10. 대화형 모드
print("\n" + "=" * 60)
print(" 대화형 모드 (종료: 'quit' 입력)")
print("=" * 60)

while True:
    try:
        user_question = input("\n질문을 입력하세요: ").strip()
        
        if user_question.lower() in ['quit', 'exit', '종료', 'q']:
            print("RAG 시스템을 종료합니다.")
            break
            
        if not user_question:
            continue
            
        print("답변 생성 중...")
        start_time = time.time()
        
        result = qa_chain.invoke({"query": user_question})
        answer = result["result"]
        response_time = time.time() - start_time
        
        print(f"\n답변: (응답시간: {response_time:.1f}초)")
        print("-" * 50)
        print(answer)
        
    except KeyboardInterrupt:
        print("\nRAG 시스템을 종료합니다.")
        break
    except Exception as e:
        print(f"오류 발생: {e}")

print("\n로컬 RAG 시스템 세션 종료!")
# Out:
# ============================================================
#  로컬 RAG 시스템 테스트
# ============================================================
#
# 【테스트 1/2】
# 질문: BlueJ에서 객체를 생성하는 방법은 무엇인가요?
# 답변 생성 중...
#
# 답변: (응답시간: 130.0초)
# --------------------------------------------------
# BlueJ에서 객체를 생성하는 방법은 다음과 같습니다:
#
# 1. **프로젝트 열기**:
#    - BlueJ를 시작한 후, Project - Open... 메뉴를 선택합니다.
#    - 표준 BlueJ 배포판의 examples 디렉토리에 있는 people 프로젝트를 선택하여 프로젝트를 열어보세요.
#
# 2. **프로젝트 열기**:
#    - 프로젝트를 열면 그림 1과 유사한 윈도우를 볼 수 있습니다.
#    - 하지만 설치 환경에 따라서 보이는 모습이 차이가 날 수도 있습니다.
#
# 3. **객체 생성하기**:
#    - BlueJ의 기본적인 특징 중 하나는, 완벽한 어플리케이션을 실행할 수 있을 뿐만 아니라 하나의 클래스에서 생성된 객체도 public 메소드들을 실행함으로써 사용자와 단일 객체간의 상호작용을 할 수 있다는 것입니다.
#    - BlueJ에서의 실행은 객체를 생성하고, 생성된 객체의 메소드 중 하나를 호출하는 것을 말합니다. 이러한 실행은 작성 완료된 클래스를 개별적으로 테스트해 볼 수 있기 때문에 어플리케이션 개발에 매우 큰 도움이 됩니다.
#
# 4. **객체 생성하기**:
#    - 메인 윈도우 중앙의 사각형들은(Database, Person, Staff, Student로 명명된 사각형들)
#    - BlueJ에서 객체를 생성하는 방법은 Tools - Use Libraries Class 메뉴를 선택하여 라이브러리 클래스로부터 객체를 생성할 수 있습니다.
#    - 팝업메뉴에 표시되는 텍스트 필드값들은 최근에 사용된 클래스들을 보여줍니다.
#    - 클래스명을 입력하고, 엔터버튼을 누르십시오. 그러면 대화상자에는 입력된 클래스의 모든 생성자 함수와 정적 메소드들의 리스트가 표시됩니다.
#
# 5. **객체 생성하기**:
#    - BlueJ에서 객체를 생성하는 방법은 Tools - Use Libraries Class 메뉴를 선택하여 라이브러리 클래스로부터 객체를 생성할 수 있습니다.
#    - 팝업메뉴에 표시되는 텍스트 필드값들은 최근에 사용된 클래스들을 보여줍니다.
#    - 클래스명을 입력하고, 엔터버튼을 누르십시오. 그러면 대화상자에는 입력된 클래스의 모든 생성자 함수와 정적 메소드들의 리스트가 표시됩니다.
#
# 이러한 방법으로 BlueJ에서 객체를 생성하여 사용자와 단일 객체간의 상호작용을 할 수 있습니다.
#
# 참조 문서:
#    1. 페이지 3: 4 1. 서문 1.1. BlueJ의 소개 본 튜토리얼은 BlueJ 프로그래밍 환경을 사용하...
#    2. 페이지 33: 34 10.기타 기능들 10.1. BlueJ로 만들지 않은 패키지 오픈하기   BlueJ는...
#
# ----------------------------------------
#
# 【테스트 2/2】
# 질문: 컴파일 오류가 발생했을 때 어떻게 확인할 수 있나요?
# 답변 생성 중...
#
# 답변: (응답시간: 117.4초)
# --------------------------------------------------
# 컴파일 오류가 발생했을 때 확인할 수 있는 방법은 다음과 같습니다:
#
# 1. **메뉴 선택**: 프로그램 실행 중 오류가 발생하면, 메인 윈도우 창의 오른쪽 상단에 위치한 "Project" 메뉴를 클릭합니다.
#
# 2. **오류 메시지 표시**: 오류 메시지가 나타나면 해당 오류 메시지를 볼 수 있습니다. 이 메시지는 오류 발생 시점에서 프로그램이 실행 중인 상태로 보여집니다.
#
# 3. **디버거 윈도우 확인**: 디버거 윈도우를 통해 오류 메시지가 표시되지 않은 경우, 오류 메시지를 볼 수 있습니다. 이는 오류 발생 시점에서 프로그램이 실행 중인 상태로 보여집니다.
#
# 4. **오류 메시지 검색**: 오류 메시지가 나타나지 않아도, 오류 메시지의 내용을 찾으려면 "Project" 메뉴에서 "Error Log..."를 선택하여 오류 로그를 볼 수 있습니다.
#
# 5. **디버거 윈도우 확인**: 디버거 윈도우에서 오류 메시지를 검색하거나, 오류 메시지가 나타나지 않은 경우에도 오류 메시지를 찾을 수 있습니다.
#
# 6. **문서에서 찾기**: 만약 위의 방법들로 오류 메시지나 오류 내용을 찾지 못한다면, "Project" 메뉴에서 "Error Log..."를 선택하여 오류 로그를 볼 수도 있습니다. 이는 프로그램 실행 중 발생한 모든 오류 메시지를 포함합니다.
#
# 이러한 방법들을 통해 컴파일 오류가 발생했을 때 확인할 수 있는 기능은 다음과 같습니다:
#
# - **메뉴 선택**: "Project" 메뉴에서 "Error Log..."를 클릭하여 오류 로그를 볼 수 있습니다.
# - **오류 메시지 표시**: 오류 메시지가 나타나면 해당 오류 메시지를 볼 수 있습니다.
# - **디버거 윈도우 확인**: 디버거 윈도우에서 오류 메시지를 검색하거나, 오류 메시지가 나타나지 않은 경우에도 오류 메시지를 찾을 수 있습니다.
#
# 이러한 방법들을 통해 컴파일 오류를 확인할 수 있으며, 필요한 경우 오류 로그를 분석하여 원인을 찾아내는 데 도움이 됩니다.
#
# 참조 문서:
#    1. 페이지 25: 프로그램 실행이 일시 중단 되면, 프로그램 실행에 의해 생성되어 실행중인 객체들의 현재  ...
#    2. 페이지 27: 28 7.2. 코드의 단계별 실행 현재 실행을 일시 중지한 상태이며(메소드는 실제로 실행이...
#
# ----------------------------------------
#
# 테스트 완료! (총 소요시간: 247.4초)
#
# ============================================================
#  대화형 모드 (종료: 'quit' 입력)
# ============================================================
# 답변 생성 중...
#
# 답변: (응답시간: 112.6초)
# --------------------------------------------------
# 새 프로젝트를 만들기 위해서는 다음의 단계를 따르면 됩니다:
#
# 1. **프로젝트 디렉토리 생성**:
#    - 메뉴에서 `Project` -> `New Project...`를 선택합니다.
#    - 파일입력 대화상자가 열립니다.
#    - 프로젝트 이름을 입력하고, 저장할 위치를 선택합니다.
#
# 2. **클래스 만들기**:
#    - 메뉴에서 `Project` -> `New Class...`를 선택합니다.
#    - 클래스 이름을 지정하고, 자바 식별자를 입력해야 합니다.
#    - 클래스 유형 중에서 선택하여 만들 수 있습니다 (추상클래스, 인터페이스, 애플릿 또는 기본적인 구상클래스).
#
# 3. **새 프로젝트 생성**:
#    - 메뉴에서 `Project` -> `New Project...`를 선택합니다.
#    - 프로젝트 이름을 입력하고, 저장할 위치를 선택합니다.
#
# 4. **클래스 편집 및 컴파일**:
#    - 클래스 아이콘을 클릭하여 클래스의 소스 코드를 편집합니다.
#    - 메뉴에서 `Project` -> `Compile...`를 선택하여 클래스를 컴파일합니다.
#
# 5. **실행하기**:
#    - 메인 윈도우 중앙의 사각형들은 (Database, Person, Staff, Student로 명명된 사각형들)
#    - 메뉴에서 `Run` 또는 `Debug` 버튼을 클릭하여 프로그램을 실행하거나 디버깅합니다.
#
# 이러한 단계를 따르면 새로운 프로젝트와 클래스를 생성하고, 이를 통해 코드를 편집하고 컴파일하며 실행할 수 있습니다.
# RAG 시스템을 종료합니다.
#
# 로컬 RAG 시스템 세션 종료!
