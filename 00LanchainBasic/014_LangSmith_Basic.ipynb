# %% [markdown]
# #### LangSmith 기본 예제

# %% [markdown]
# ##### 1) 라이브러리 설치

# %%
#%pip install -q langchain langchain-openai langsmith

# %% [markdown]
# ##### 2) OpenAI 인증키 설정

# %%
import os
from dotenv import load_dotenv
# .env 파일을 불러와서 환경 변수로 설정
load_dotenv("../.env")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:5])
# Out:
# gsk_g

# %% [markdown]
# ##### LangSmith와 LangChain을 활용한 기본 로깅 예제

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
from langsmith import traceable

# LangSmith API Key 설정
os.environ["LANGSMITH_TRACING"] = os.getenv("LANGSMITH_TRACING")  # LangSmith 활성화
os.environ["LANGSMITH_API_KEY"] = os.getenv("LANGSMITH_API_KEY")  # API Key 불러오기
os.environ["LANGSMITH_PROJECT"] = os.getenv("LANGSMITH_PROJECT")   # 프로젝트 이름 설정
os.environ["LANGSMITH_ENDPOINT"] = os.getenv("LANGSMITH_ENDPOINT")   # EndPoint 설정

# LLM 모델 설정 (OpenAI 사용)
#llm = ChatOpenAI(model="gpt-3.5-turbo")
llm = ChatOpenAI(
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    model="meta-llama/llama-4-scout-17b-16e-instruct",  # Spring AI와 동일한 모델
    temperature=0.7
)

# LangSmith로 실행 추적
@traceable(run_type="chain", name="Simple_Chain")
def ask_question(question: str):

    # 개별 메시지 템플릿 정의
    # 역할을 지정
    system_message = SystemMessagePromptTemplate.from_template(
        "당신은 유용한 AI 비서입니다."
    )
    
    # 하고 싶은 질문
    user_message = HumanMessagePromptTemplate.from_template(
        "{question}"
    )
    
    chat_prompt = ChatPromptTemplate.from_messages([
        system_message,
        user_message,
    ])
    
    messages = chat_prompt.format_messages(question=question)
    response = llm.invoke(messages)

    return response.content

# 테스트 실행
question = "LangGraph와 LangChain의 차이점은 무엇인가요?"
answer = ask_question(question)

# 결과 출력
print("\n🔹 [AI 답변]:")
print(answer)
# Out:
# 🔹 [AI 답변]:
# LangGraph와 LangChain은 모두 언어 모델을 활용하여 애플리케이션을 구축하기 위한 프레임워크이지만, 두 프레임워크는 다른 디자인 철학과 사용 사례에 중점을 둡니다.
#
# LangChain은 언어 모델을 사용하여 애플리케이션을 구축하기 위한 오픈 소스 프레임워크입니다. 대규모 언어 모델(LLM)을 통합하여 컨텍스트 인식이 가능하고 자연어 처리 기능을 갖춘 애플리케이션을 개발할 수 있습니다. LangChain은 에이전트, 프롬프트 템플릿 및 메모리 모듈과 같은 다양한 구성 요소로 구성되어 있어 개발자가 언어 모델을 사용하여 애플리케이션을 더 쉽게 구축할 수 있습니다.
#
# LangGraph는 LangChain을 기반으로 구축된 고급 워크플로우 관리 및 오케스트레이션 프레임워크입니다. LangGraph를 사용하면 여러 LLM을 연결하여 다단계 워크플로우를 만들 수 있습니다. LangGraph는 여러 에이전트를 오케스트레이션하고, 중간 단계를 저장하고, 작업을 원활하게 조정하여 애플리케이션에서 더욱 정교하고 자동화된 워크플로우를 지원하도록 설계되었습니다.
#
# LangChain과 LangGraph의 주요 차이점은 다음과 같습니다.
#
# * 설계 목적: LangChain은 언어 모델을 사용하여 애플리케이션을 구축하기 위한 기본 프레임워크입니다. LangGraph는 LangChain을 기반으로 구축되었으며 고급 워크플로우 관리 및 오케스트레이션에 중점을 둡니다.
# * 구성 요소: LangChain은 에이전트, 프롬프트 템플릿 및 메모리 모듈과 같은 다양한 구성 요소를 제공합니다. LangGraph는 여러 LLM, 에이전트 및 워크플로우 오케스트레이션 구성 요소를 지원하여 다단계 워크플로우를 만들 수 있습니다.
# * 사용 사례: LangChain은 자연어 처리 기능이 있는 애플리케이션을 구축하는 데 적합합니다. LangGraph는 다단계 워크플로우 및 여러 에이전트가 포함된 보다 복잡한 애플리케이션을 구축하는 데 적합합니다.
#
# 요약하면 LangChain은 언어 모델을 사용하여 애플리케이션을 구축하기 위한 기본 프레임워크인 반면, LangGraph는 LangChain을 기반으로 구축된 고급 워크플로우 관리 및 오케스트레이션 프레임워크입니다.
